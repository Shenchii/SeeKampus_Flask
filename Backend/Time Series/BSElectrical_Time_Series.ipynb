# %%
import pandas as pd
import prophet as Prophet
from datetime import datetime
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
letran_electrical = pd.read_csv('CSV/board-exam-results - LETRAN-Electrical.csv')

letran_electrical['Year'] = letran_electrical['Time Date'].apply(lambda x: str(x)[-4:])
letran_electrical['Month'] = letran_electrical['Time Date'].apply(lambda x: str(x)[-6:-4])
letran_electrical['Day'] = letran_electrical['Time Date'].apply(lambda x: str(x)[:-6])
letran_electrical['ds'] = pd.DatetimeIndex(letran_electrical['Year']+'-'+letran_electrical['Month']+'-'+letran_electrical['Day'])

letran_electrical.drop(['Time Date', 'School', 'Course', 'Year', 'Month', 'Day'], axis=1, inplace=True)
letran_electrical.columns = ['y', 'ds']

m = Prophet.Prophet(interval_width=0.95)
m.add_seasonality(name='yearly', period=365.25, fourier_order=10)
m.add_seasonality(name='semi-annual', period=365.25/2, fourier_order=10)
letran_electrical_model = m.fit(letran_electrical)

# Create a list of dates for which you want to make predictions
specific_dates = [datetime(2023, 4, 24), datetime(2023, 9, 6), datetime(2024, 4, 24), datetime(2024, 9, 6), datetime(2025, 4, 24), datetime(2025, 9, 6), datetime(2026, 4, 24), datetime(2026, 9, 6), datetime(2027, 4, 24), datetime(2027, 9, 6), datetime(2028, 4, 24), datetime(2028, 9, 6), datetime(2029, 4, 24), datetime(2029, 9, 6), datetime(2030, 4, 24), datetime(2030, 9, 6)]


# Create a dataframe with those specific dates
letran_electrical_future = pd.DataFrame({'ds': specific_dates})

# Get predictions for those specific dates
letran_electrical_forecast = m.predict(letran_electrical_future)
letran_electrical_forecast['yhat'] = letran_electrical_forecast['yhat'].clip(lower=0, upper=100).round()
# Out:
# 11:46:14 - cmdstanpy - INFO - Chain [1] start processing
# 11:46:14 - cmdstanpy - INFO - Chain [1] done processing

# %%
letran_electrical_forecast[['ds', 'yhat']]
# Out:
#            ds   yhat
# 0  2023-04-24  100.0
# 1  2023-09-06   65.0
# 2  2024-04-24   90.0
# 3  2024-09-06   69.0
# 4  2025-04-24   98.0
# 5  2025-09-06   72.0
# 6  2026-04-24  100.0
# 7  2026-09-06   75.0
# 8  2027-04-24  100.0
# 9  2027-09-06   79.0
# 10 2028-04-24  100.0
# 11 2028-09-06   83.0
# 12 2029-04-24  100.0
# 13 2029-09-06   86.0
# 14 2030-04-24  100.0
# 15 2030-09-06   90.0

# %%
letran_electrical_plot = m.plot(letran_electrical_forecast)

# %%
lpu_electrical = pd.read_csv('CSV/board-exam-results - LPU - Electrical.csv')

lpu_electrical['Year'] = lpu_electrical['Time Date'].apply(lambda x: str(x)[-4:])
lpu_electrical['Month'] = lpu_electrical['Time Date'].apply(lambda x: str(x)[-6:-4])
lpu_electrical['Day'] = lpu_electrical['Time Date'].apply(lambda x: str(x)[:-6])
lpu_electrical['ds'] = pd.DatetimeIndex(lpu_electrical['Year']+'-'+lpu_electrical['Month']+'-'+lpu_electrical['Day'])

lpu_electrical.drop(['Time Date', 'School', 'Course', 'Year', 'Month', 'Day'], axis=1, inplace=True)
lpu_electrical.columns = ['y', 'ds']

m = Prophet.Prophet(interval_width=0.95)
m.add_seasonality(name='yearly', period=365.25, fourier_order=10)
m.add_seasonality(name='semi-annual', period=365.25/2, fourier_order=10)
lpu_electrical_model = m.fit(lpu_electrical)

# Create a list of dates for which you want to make predictions
specific_dates = [datetime(2023, 4, 24), datetime(2023, 9, 6), datetime(2024, 4, 24), datetime(2024, 9, 6), datetime(2025, 4, 24), datetime(2025, 9, 6), datetime(2026, 4, 24), datetime(2026, 9, 6), datetime(2027, 4, 24), datetime(2027, 9, 6), datetime(2028, 4, 24), datetime(2028, 9, 6), datetime(2029, 4, 24), datetime(2029, 9, 6), datetime(2030, 4, 24), datetime(2030, 9, 6)]

# Create a dataframe with those specific dates
lpu_electrical_future = pd.DataFrame({'ds': specific_dates})

# Get predictions for those specific dates
lpu_electrical_forecast = m.predict(lpu_electrical_future)
lpu_electrical_forecast['yhat'] = lpu_electrical_forecast['yhat'].clip(lower=0, upper=100).round()
# Out:
# 11:50:07 - cmdstanpy - INFO - Chain [1] start processing
# 11:50:07 - cmdstanpy - INFO - Chain [1] done processing

# %%
lpu_electrical_forecast[['ds', 'yhat']]
# Out:
#            ds   yhat
# 0  2023-04-24  100.0
# 1  2023-09-06   73.0
# 2  2024-04-24  100.0
# 3  2024-09-06   65.0
# 4  2025-04-24  100.0
# 5  2025-09-06   74.0
# 6  2026-04-24  100.0
# 7  2026-09-06   82.0
# 8  2027-04-24  100.0
# 9  2027-09-06   89.0
# 10 2028-04-24  100.0
# 11 2028-09-06   81.0
# 12 2029-04-24  100.0
# 13 2029-09-06   90.0
# 14 2030-04-24  100.0
# 15 2030-09-06   98.0

# %%
lpu_electrical_plot = m.plot(lpu_electrical_forecast)

# %%
perps_electrical = pd.read_csv('CSV/board-exam-results - PERP-Electrical.csv')

perps_electrical['Year'] = perps_electrical['Time Date'].apply(lambda x: str(x)[-4:])
perps_electrical['Month'] = perps_electrical['Time Date'].apply(lambda x: str(x)[-6:-4])
perps_electrical['Day'] = perps_electrical['Time Date'].apply(lambda x: str(x)[:-6])
perps_electrical['ds'] = pd.DatetimeIndex(perps_electrical['Year']+'-'+perps_electrical['Month']+'-'+perps_electrical['Day'])

perps_electrical.drop(['Time Date', 'School', 'Course', 'Year', 'Month', 'Day'], axis=1, inplace=True)
perps_electrical.columns = ['y', 'ds']

m = Prophet.Prophet(interval_width=0.95)
m.add_seasonality(name='yearly', period=365.25, fourier_order=10)
m.add_seasonality(name='semi-annual', period=365.25/2, fourier_order=10)
perps_electrical_model = m.fit(perps_electrical)

# Create a list of dates for which you want to make predictions
specific_dates = [datetime(2023, 4, 24), datetime(2023, 9, 6), datetime(2024, 4, 24), datetime(2024, 9, 6), datetime(2025, 4, 24), datetime(2025, 9, 6), datetime(2026, 4, 24), datetime(2026, 9, 6), datetime(2027, 4, 24), datetime(2027, 9, 6), datetime(2028, 4, 24), datetime(2028, 9, 6), datetime(2029, 4, 24), datetime(2029, 9, 6), datetime(2030, 4, 24), datetime(2030, 9, 6)]

# Create a dataframe with those specific dates
perps_electrical_future = pd.DataFrame({'ds': specific_dates})

# Get predictions for those specific dates
perps_electrical_forecast = m.predict(perps_electrical_future)
perps_electrical_forecast['yhat'] = perps_electrical_forecast['yhat'].clip(lower=0, upper=100).round()
# Out:
# 12:22:39 - cmdstanpy - INFO - Chain [1] start processing
# 12:22:39 - cmdstanpy - INFO - Chain [1] done processing

# %%
perps_electrical_forecast[['ds', 'yhat']]
# Out:
#            ds   yhat
# 0  2023-04-24   41.0
# 1  2023-09-06   46.0
# 2  2024-04-24   75.0
# 3  2024-09-06   52.0
# 4  2025-04-24   73.0
# 5  2025-09-06   58.0
# 6  2026-04-24   71.0
# 7  2026-09-06   65.0
# 8  2027-04-24   69.0
# 9  2027-09-06   74.0
# 10 2028-04-24  100.0
# 11 2028-09-06   80.0
# 12 2029-04-24  100.0
# 13 2029-09-06   86.0
# 14 2030-04-24   99.0
# 15 2030-09-06   93.0

# %%
perps_electrical_plot = m.plot(perps_electrical_forecast)
